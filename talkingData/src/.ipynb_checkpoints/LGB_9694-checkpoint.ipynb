# %%
VALIDATE = False

MAX_ROUNDS = 1000
EARLY_STOP = 50
OPT_ROUNDS = 680

FULL_OUTFILE = 'output/sub_lgbm_r_to_python_nocv.csv'
VALID_OUTFILE = 'output/sub_lgbm_r_to_python_withcv.csv'

import pandas as pd
import time
import numpy as np
from sklearn.model_selection import train_test_split 
import lightgbm as lgb

path = 'input/'

dtypes = {
        'ip'            : 'uint32',
        'app'           : 'uint16',
        'device'        : 'uint16',
        'os'            : 'uint16',
        'channel'       : 'uint16',
        'is_attributed' : 'uint8',
        'click_id'      : 'uint32'
        }

print('load train...')
train_cols = ['ip','app','device','os', 'channel', 'click_time', 'is_attributed']
train_df = pd.read_csv(path+"train.csv", skiprows=range(1,84903891), nrows=100000000,dtype=dtypes, usecols=train_cols)

import gc

len_train = len(train_df)

gc.collect()

print('data prep...')
l
most_freq_hours_in_test_data = [4, 5, 9, 10, 13, 14]
least_freq_hours_in_test_data = [6, 11, 15]


def prep_data( df ):
    
    df['hour'] = pd.to_datetime(df.click_time).dt.hour.astype('uint8')
    df['day'] = pd.to_datetime(df.click_time).dt.day.astype('uint8')
    df['weekday'] = pd.to_datetime(df.click_time).dt.weekday.astype('uint8')
    
    df.drop(['click_time'], axis=1, inplace=True)
    gc.collect()
    
    df['in_test_hh'] = (   3 
                         - 2*df['hour'].isin(  most_freq_hours_in_test_data ) 
                         - 1*df['hour'].isin( least_freq_hours_in_test_data ) ).astype('uint8')
    print( df.info() )

    print('group by : ip_day_test_hh')
    gp = df[['ip', 'day', 'weekday', 'in_test_hh', 'channel']].groupby(by=['ip', 'day','weekday', 
             'in_test_hh'])[['channel']].count().reset_index().rename(index=str, 
             columns={'channel': 'nip_day_test_hh'})
    df = df.merge(gp, on=['ip','day','weekday', 'in_test_hh'], how='left')
    del gp
    df.drop(['in_test_hh'], axis=1, inplace=True)
    print( "nip_day_test_hh max value = ", df.nip_day_test_hh.max() )
    df['nip_day_test_hh'] = df['nip_day_test_hh'].astype('uint32')
    gc.collect()
    print( df.info() )

    print('group by : ip_day_hh')
    gp = df[['ip', 'day', 'weekday', 'hour', 'channel']].groupby(by=['ip', 'day', 'weekday', 
             'hour'])[['channel']].count().reset_index().rename(index=str, 
             columns={'channel': 'nip_day_hh'})
    df = df.merge(gp, on=['ip','day','weekday', 'hour'], how='left')
    del gp
    print( "nip_day_hh max value = ", df.nip_day_hh.max() )
    df['nip_day_hh'] = df['nip_day_hh'].astype('uint16')
    gc.collect()
    print( df.info() )

    print('group by : ip_hh_os')
    gp = df[['ip', 'day', 'weekday', 'os', 'hour', 'channel']].groupby(by=['ip', 'os', 'day','weekday', 
             'hour'])[['channel']].count().reset_index().rename(index=str, 
             columns={'channel': 'nip_hh_os'})
    df = df.merge(gp, on=['ip','os','hour','weekday', 'day'], how='left')
    del gp
    print( "nip_hh_os max value = ", df.nip_hh_os.max() )
    df['nip_hh_os'] = df['nip_hh_os'].astype('uint16')
    gc.collect()
    print( df.info() )

    print('group by : ip_hh_app')
    gp = df[['ip', 'app', 'hour','weekday',  'day', 'channel']].groupby(by=['ip', 'app','weekday',  'day',
             'hour'])[['channel']].count().reset_index().rename(index=str, 
             columns={'channel': 'nip_hh_app'})
    df = df.merge(gp, on=['ip','app','weekday', 'hour','day'], how='left')
    del gp
    print( "nip_hh_app max value = ", df.nip_hh_app.max() )
    df['nip_hh_app'] = df['nip_hh_app'].astype('uint16')
    gc.collect()
    print( df.info() )

    print('group by : ip_hh_dev')
    gp = df[['ip', 'device', 'hour','weekday',  'day', 'channel']].groupby(by=['ip', 'device', 'weekday', 'day',
             'hour'])[['channel']].count().reset_index().rename(index=str, 
             columns={'channel': 'nip_hh_dev'})
    df = df.merge(gp, on=['ip','device','weekday', 'day','hour'], how='left')
    del gp
    print( "nip_hh_dev max value = ", df.nip_hh_dev.max() )
    df['nip_hh_dev'] = df['nip_hh_dev'].astype('uint32')
    gc.collect()
    print( df.info() )

    df.drop( ['ip','day'], axis=1, inplace=True )
    gc.collect()
    print( df.info() )
    
    return( df )

#---------------------------------------------------------------------------------

print( "Train info before: ")
print( train_df.info() )
train_df = prep_data( train_df )
gc.collect()
print( "Train info after: ")
print( train_df.info() )

print("vars and data type: ")
train_df.info()

metrics = 'auc'
lgb_params = {
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric':metrics,
        'learning_rate': 0.1,
        'num_leaves': 7,  # we should let it be smaller than 2^(max_depth)
        'max_depth': 4,  # -1 means no limit
        'min_child_samples': 100,  # Minimum number of data need in a child(min_data_in_leaf)
        'max_bin': 100,  # Number of bucketed bin for feature values
        'subsample': 0.7,  # Subsample ratio of the training instance.
        'subsample_freq': 1,  # frequence of subsample, <=0 means no enable
        'colsample_bytree': 0.7,  # Subsample ratio of columns when constructing each tree.
        'min_child_weight': 0,  # Minimum sum of instance weight(hessian) needed in a child(leaf)
        'min_split_gain': 0,  # lambda_l1, lambda_l2 and min_gain_to_split to regularization
        'nthread': 8,
        'verbose': 0,
        'scale_pos_weight':99.7, # because training data is extremely unbalanced 
        'metric':metrics
}

target = 'is_attributed'
predictors = ['app','device','os', 'channel', 'hour', 'nip_day_test_hh', 'nip_day_hh',
              'nip_hh_os', 'nip_hh_app', 'nip_hh_dev']
categorical = ['app', 'device', 'os', 'channel', 'hour']

print(train_df.head(5))

if VALIDATE:

    train_df, val_df = train_test_split( train_df, train_size=.95, shuffle=False )

    print(train_df.info())
    print(val_df.info())

    print("train size: ", len(train_df))
    print("valid size: ", len(val_df))

    gc.collect()

    print("Training...")

    num_boost_round=MAX_ROUNDS
    early_stopping_rounds=EARLY_STOP

    xgtrain = lgb.Dataset(train_df[predictors].values, label=train_df[target].values,
                          feature_name=predictors,
                          categorical_feature=categorical
                          )
    del train_df
    gc.collect()

    xgvalid = lgb.Dataset(val_df[predictors].values, label=val_df[target].values,
                          feature_name=predictors,
                          categorical_feature=categorical
                          )
    del val_df
    gc.collect()

    evals_results = {}

    bst = lgb.train(lgb_params, 
                     xgtrain, 
                     valid_sets= [xgvalid], 
                     valid_names=['valid'], 
                     evals_result=evals_results, 
                     num_boost_round=num_boost_round,
                     early_stopping_rounds=early_stopping_rounds,
                     verbose_eval=10, 
                     feval=None)

    n_estimators = bst.best_iteration

    print("\nModel Report")
    print("n_estimators : ", n_estimators)
    print(metrics+":", evals_results['valid'][metrics][n_estimators-1])
    
    outfile = VALID_OUTFILE
    
    del xgvalid

else:

    print(train_df.info())

    print("train size: ", len(train_df))

    gc.collect()

    print("Training...")

    num_boost_round=OPT_ROUNDS

    xgtrain = lgb.Dataset(train_df[predictors].values, label=train_df[target].values,
                          feature_name=predictors,
                          categorical_feature=categorical
                          )
    del train_df
    gc.collect()

    bst = lgb.train(lgb_params, 
                     xgtrain, 
                     num_boost_round=num_boost_round,
                     verbose_eval=10, 
                     feval=None)
                     
    outfile = FULL_OUTFILE

del xgtrain
gc.collect()

print('load test...')
test_cols = ['ip','app','device','os', 'channel', 'click_time', 'click_id']
test_df = pd.read_csv(path+"test.csv", dtype=dtypes, usecols=test_cols)

test_df = prep_data( test_df )
gc.collect()

sub = pd.DataFrame()
sub['click_id'] = test_df['click_id']

print("Predicting...")
sub['is_attributed'] = bst.predict(test_df[predictors])
print("writing...")
sub.to_csv(outfile, index=False, float_format='%.9f')
print("done...")
print(sub.info())
# Out:
# load train...
# data prep...
# Train info before:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000000 entries, 0 to 99999999
# Data columns (total 7 columns):
# ip               uint32
# app              uint16
# device           uint16
# os               uint16
# channel          uint16
# click_time       object
# is_attributed    uint8
# dtypes: object(1), uint16(4), uint32(1), uint8(1)
# memory usage: 2.0+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000000 entries, 0 to 99999999
# Data columns (total 9 columns):
# ip               uint32
# app              uint16
# device           uint16
# os               uint16
# channel          uint16
# is_attributed    uint8
# hour             uint8
# day              uint8
# in_test_hh       uint8
# dtypes: uint16(4), uint32(1), uint8(4)
# memory usage: 1.5 GB
# None
# group by : ip_day_test_hh
# nip_day_test_hh max value =  174383
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 9 columns):
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# dtypes: uint16(4), uint32(2), uint8(3)
# memory usage: 2.5 GB
# None
# group by : ip_day_hh
# nip_day_hh max value =  43958
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 10 columns):
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# dtypes: uint16(5), uint32(2), uint8(3)
# memory usage: 2.7 GB
# None
# group by : ip_hh_os
# nip_hh_os max value =  9382
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 11 columns):
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# dtypes: uint16(6), uint32(2), uint8(3)
# memory usage: 2.9 GB
# None
# group by : ip_hh_app
# nip_hh_app max value =  7592
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 12 columns):
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# dtypes: uint16(7), uint32(2), uint8(3)
# memory usage: 3.1 GB
# None
# group by : ip_hh_dev
# nip_hh_dev max value =  37581
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 13 columns):
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# nip_hh_dev         uint32
# dtypes: uint16(7), uint32(3), uint8(3)
# memory usage: 3.4 GB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 11 columns):
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# nip_hh_dev         uint32
# dtypes: uint16(7), uint32(2), uint8(2)
# memory usage: 3.0 GB
# None
# Train info after:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 11 columns):
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# nip_hh_dev         uint32
# dtypes: uint16(7), uint32(2), uint8(2)
# memory usage: 3.0 GB
# None
# vars and data type:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 11 columns):
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# nip_hh_dev         uint32
# dtypes: uint16(7), uint32(2), uint8(2)
# memory usage: 3.0 GB
#    app  device  os  channel  is_attributed  hour  nip_day_test_hh  nip_day_hh  \
# 0   15       1  27      245              0     4              341          15
# 1   12       1  13      265              0     4              420          48
# 2   11       1  17      219              0     4              232           4
# 3   65       1  15      317              0     4             1070          54
# 4   12       1  22      178              0     4             2252         127
#
#    nip_hh_os  nip_hh_app  nip_hh_dev
# 0          2           2          14
# 1          2           4          48
# 2          4           1           4
# 3          1           1          54
# 4          6           9          96
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000000 entries, 0 to 99999999
# Data columns (total 11 columns):
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# is_attributed      uint8
# hour               uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# nip_hh_dev         uint32
# dtypes: uint16(7), uint32(2), uint8(2)
# memory usage: 3.0 GB
# None
# train size:  100000000
# Training...
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# load test...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18790469 entries, 0 to 18790468
# Data columns (total 9 columns):
# click_id      uint32
# ip            uint32
# app           uint16
# device        uint16
# os            uint16
# channel       uint16
# hour          uint8
# day           uint8
# in_test_hh    uint8
# dtypes: uint16(4), uint32(2), uint8(3)
# memory usage: 340.5 MB
# None
# group by : ip_day_test_hh
# nip_day_test_hh max value =  182513
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18790469 entries, 0 to 18790468
# Data columns (total 9 columns):
# click_id           uint32
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# dtypes: uint16(4), uint32(3), uint8(2)
# memory usage: 537.6 MB
# None
# group by : ip_day_hh
# nip_day_hh max value =  40231
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18790469 entries, 0 to 18790468
# Data columns (total 10 columns):
# click_id           uint32
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# dtypes: uint16(5), uint32(3), uint8(2)
# memory usage: 573.4 MB
# None
# group by : ip_hh_os
# nip_hh_os max value =  8224
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18790469 entries, 0 to 18790468
# Data columns (total 11 columns):
# click_id           uint32
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# dtypes: uint16(6), uint32(3), uint8(2)
# memory usage: 609.3 MB
# None
# group by : ip_hh_app
# nip_hh_app max value =  6250
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18790469 entries, 0 to 18790468
# Data columns (total 12 columns):
# click_id           uint32
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# dtypes: uint16(7), uint32(3), uint8(2)
# memory usage: 645.1 MB
# None
# group by : ip_hh_dev
# nip_hh_dev max value =  33476
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18790469 entries, 0 to 18790468
# Data columns (total 13 columns):
# click_id           uint32
# ip                 uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# hour               uint8
# day                uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# nip_hh_dev         uint32
# dtypes: uint16(7), uint32(4), uint8(2)
# memory usage: 716.8 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18790469 entries, 0 to 18790468
# Data columns (total 11 columns):
# click_id           uint32
# app                uint16
# device             uint16
# os                 uint16
# channel            uint16
# hour               uint8
# nip_day_test_hh    uint32
# nip_day_hh         uint16
# nip_hh_os          uint16
# nip_hh_app         uint16
# nip_hh_dev         uint32
# dtypes: uint16(7), uint32(3), uint8(1)
# memory usage: 627.2 MB
# None
# Predicting...
# writing...
# done...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18790469 entries, 0 to 18790468
# Data columns (total 2 columns):
# click_id         uint32
# is_attributed    float64
# dtypes: float64(1), uint32(1)
# memory usage: 358.4 MB
# None

# %%
# Out:
# __init__.py  demo.ipynb   input/       output/      src/
