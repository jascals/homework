# %%
import numpy as np
import sklearn
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits

# Random state.
RS = 20150101

import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
import matplotlib

# We import seaborn to make nice plots.
import seaborn as sns
sns.set_style('darkgrid')
sns.set_palette('muted')
sns.set_context("notebook", font_scale=1.5,
                rc={"lines.linewidth": 2.5})

import pandas as pd
# digits = load_digits()
print('load train...')


dtypes = {
        'ip'            : 'uint32',
        'app'           : 'uint16',
        'device'        : 'uint16',
        'os'            : 'uint16',
        'channel'       : 'uint16',
        'is_attributed' : 'uint8',
        'click_id'      : 'uint32'
        }
train_cols = ['ip','app','device','os', 'channel', 'click_time', 'is_attributed']
train_df = pd.read_csv("../input/train_sample.csv", dtype=dtypes,usecols=train_cols)

train_df.head()
# train_df['app'] = train_df['app'].astype(np.int64)
# train_df['hour'] = pd.to_datetime(train_df.click_time).dt.hour.astype('uint8')
# train_df['day'] = pd.to_datetime(train_df.click_time).dt.day.astype('uint8')
train_df = train_df.drop(['click_time'], axis=1, inplace=True)
label_df = train_df[['is_attributed']]
train_df = train_df.drop(['is_attributed'], axis=1)

label_df.head()
train_df.head()

# We first reorder the data points according to the handwritten numbers.
X = np.vstack(train_df.values)
y = np.hstack(label_df.values)
digits_proj = TSNE(random_state=RS).fit_transform(X)

def scatter(x, colors):
    # We choose a color palette with seaborn.
    palette = np.array(sns.color_palette("hls", 10))

    # We create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40,
                    c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')

    # We add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth=5, foreground="w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts

scatter(digits_proj, y)
plt.savefig('digits_tsne-generated.png', dpi=120)
plt.show()
# Out:
# load train...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-8ec2f656bc02> in <module>()
#      40 # train_df['day'] = pd.to_datetime(train_df.click_time).dt.day.astype('uint8')
#      41 train_df = train_df.drop(['click_time'], axis=1, inplace=True)
# ---> 42 label_df = train_df[['is_attributed']]
#      43 train_df = train_df.drop(['is_attributed'], axis=1)
#      44
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import pandas as pd
train = pd.read_csv('../input/train_sample.csv')

# %%
train.head()
# Out:
#        ip  app  device  os  channel           click_time attributed_time  \
# 0   87540   12       1  13      497  2017-11-07 09:30:38             NaN
# 1  105560   25       1  17      259  2017-11-07 13:40:27             NaN
# 2  101424   12       1  19      212  2017-11-07 18:05:24             NaN
# 3   94584   13       1  13      477  2017-11-07 04:58:08             NaN
# 4   68413   12       1   1      178  2017-11-09 09:00:09             NaN
#
#    is_attributed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
label = train['is_attributed']
train = train.drop(['ip', 'is_attributed', 'attributed_time', 'click_time', 'channel', 'os'], axis = 1)
X = np.vstack(train.values)
y = np.hstack(label.values)
train.head()
# Out:
#    app  device
# 0   12       1
# 1   25       1
# 2   12       1
# 3   13       1
# 4   12       1

# %%
digits_proj = TSNE(random_state=RS).fit_transform(X)

# %%
def scatter(x, colors):
    # We choose a color palette with seaborn.
    palette = np.array(sns.color_palette("hls", 10))

    # We create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40,
                    c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')

    # We add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth=5, foreground="w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts

scatter(digits_proj, y)
plt.savefig('digits_tsne-generated.png', dpi=120)
plt.show()
